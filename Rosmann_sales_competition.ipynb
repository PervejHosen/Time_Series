# %%
import pandas as pd

# %%
train_df=pd.read_csv("/content/drive/MyDrive/Python/Datasets/Rosmann Competition/train.csv")
# Out:
# <ipython-input-4-105496c3795c>:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df=pd.read_csv("/content/drive/MyDrive/Python/Datasets/Rosmann Competition/train.csv")

# %%
train_df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  7/31/2015   5263        555     1      1            0
# 1      2          5  7/31/2015   6064        625     1      1            0
# 2      3          5  7/31/2015   8314        821     1      1            0
# 3      4          5  7/31/2015  13995       1498     1      1            0
# 4      5          5  7/31/2015   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store_df=pd.read_csv("/content/drive/MyDrive/Python/Datasets/Rosmann Competition/store.csv")

# %%
store_df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
merged_df=train_df.merge(store_df, how='left', on='Store')
merged_df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  7/31/2015   5263        555     1      1            0
# 1      2          5  7/31/2015   6064        625     1      1            0
# 2      3          5  7/31/2015   8314        821     1      1            0
# 3      4          5  7/31/2015  13995       1498     1      1            0
# 4      5          5  7/31/2015   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
merged_df.shape
# Out:
# (1017209, 18)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %%
test_df=pd.read_csv("/content/drive/MyDrive/Python/Datasets/Rosmann Competition/test.csv")

# %%
test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
merged_test_df = test_df.merge(store_df, how='left', on='Store')
merged_test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0
#
#   StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         c          a               1270.0                        9.0
# 1         a          a              14130.0                       12.0
# 2         a          c              24000.0                        4.0
# 3         a          a               7520.0                       10.0
# 4         a          c               2030.0                        8.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
merged_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41088 entries, 0 to 41087
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         41088 non-null  int64
#  1   Store                      41088 non-null  int64
#  2   DayOfWeek                  41088 non-null  int64
#  3   Date                       41088 non-null  object
#  4   Open                       41077 non-null  float64
#  5   Promo                      41088 non-null  int64
#  6   StateHoliday               41088 non-null  object
#  7   SchoolHoliday              41088 non-null  int64
#  8   StoreType                  41088 non-null  object
#  9   Assortment                 41088 non-null  object
#  10  CompetitionDistance        40992 non-null  float64
#  11  CompetitionOpenSinceMonth  25872 non-null  float64
#  12  CompetitionOpenSinceYear   25872 non-null  float64
# ...

# %%
round(merged_df.describe().T,2)
# Out:
#                                count     mean      std     min     25%  \
# Store                      1017209.0   558.43   321.91     1.0   280.0
# DayOfWeek                  1017209.0     4.00     2.00     1.0     2.0
# Sales                      1017209.0  5773.82  3849.93     0.0  3727.0
# Customers                  1017209.0   633.15   464.41     0.0   405.0
# Open                       1017209.0     0.83     0.38     0.0     1.0
# Promo                      1017209.0     0.38     0.49     0.0     0.0
# SchoolHoliday              1017209.0     0.18     0.38     0.0     0.0
# CompetitionDistance        1014567.0  5430.09  7715.32    20.0   710.0
# CompetitionOpenSinceMonth   693861.0     7.22     3.21     1.0     4.0
# CompetitionOpenSinceYear    693861.0  2008.69     5.99  1900.0  2006.0
# Promo2                     1017209.0     0.50     0.50     0.0     0.0
# Promo2SinceWeek             509178.0    23.27    14.10     1.0    13.0
# ...

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df['Date'] = pd.to_datetime(merged_df.Date)

# %%
merged_test_df['Date'] = pd.to_datetime(merged_test_df.Date)

# %%
merged_df.Date.min(), merged_df.Date.max()
# Out:
# (Timestamp('2013-01-01 00:00:00'), Timestamp('2015-07-31 00:00:00'))

# %%
merged_test_df.Date.min(), merged_test_df.Date.max()
# Out:
# (Timestamp('2015-08-01 00:00:00'), Timestamp('2015-09-17 00:00:00'))

# %% [markdown]
# # **EDA & Visualizations**

# %% [markdown]
# Lets study the distribution of the target 'Sales' column.

# %%
import seaborn as sns
sns.histplot(data=merged_df, x='Sales')
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# Can we explain why the sales are 0 on so many dates?
# Lets check if this is because the store was closed.

# %%
merged_df.Open.value_counts()
# Out:
# 1    844392
# 0    172817
# Name: Open, dtype: int64

# %%
merged_df.Sales.value_counts()[0]
# Out:
# 172871

# %% [markdown]
# to make our modeling simple, lets simply exclude the dates when the store was closed(we can handle it as a special case when making predictions.

# %%
merged_df = merged_df[merged_df.Open == 1].copy()

# %%
sns.histplot(data=merged_df, x='Sales');

# %% [markdown]
# Lets explore some other columns

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
temp_df = merged_df.sample(40000)
sns.scatterplot(x=temp_df.Sales, y=temp_df.Customers, hue=temp_df.Date.dt.year,alpha=0.8)
plt.title("Sales Vs Customers")
plt.show()

# %%
plt.figure(figsize=(18,8))
temp_df=merged_df.sample(10000)
sns.scatterplot(x=temp_df.Store, y=temp_df.Sales, hue=temp_df.Date.dt.year, alpha=0.8)
plt.title("Stores vs Sales")
plt.show()

# %%
sns.barplot(data=merged_df, x='DayOfWeek', y='Sales')
# Out:
# <Axes: xlabel='DayOfWeek', ylabel='Sales'>

# %%
sns.barplot(data=merged_df, x='Promo', y='Sales')
# Out:
# <Axes: xlabel='Promo', ylabel='Sales'>

# %%
merged_df.corr()['Sales'].sort_values(ascending=False)
# Out:
# <ipython-input-38-7b6177dcfa65>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_df.corr()['Sales'].sort_values(ascending=False)
# Sales                        1.000000
# Customers                    0.823597
# Promo                        0.368145
# Promo2SinceWeek              0.095311
# SchoolHoliday                0.038617
# CompetitionOpenSinceYear     0.016101
# Store                        0.007710
# Promo2SinceYear             -0.034713
# CompetitionDistance         -0.036396
# CompetitionOpenSinceMonth   -0.043489
# Promo2                      -0.127596
# DayOfWeek                   -0.178736
# Open                              NaN
# Name: Sales, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
merged_df['Day']= merged_df.Date.dt.day
merged_df['Month']= merged_df.Date.dt.month
merged_df['Year']= merged_df.Date.dt.year

# %%
merged_test_df['Day']= merged_test_df.Date.dt.day
merged_test_df['Month']= merged_test_df.Date.dt.month
merged_test_df['Year']= merged_test_df.Date.dt.year

# %%
sns.barplot(data=merged_df, x='Year', y='Sales')
# Out:
# <Axes: xlabel='Year', ylabel='Sales'>

# %%
sns.barplot(data=merged_df, x='Month', y='Sales')
# Out:
# <Axes: xlabel='Month', ylabel='Sales'>

# %% [markdown]
# # Train, Test Validation Split

# %%
len(merged_df)
# Out:
# 844392

# %%
train_size = int(.75 * len(merged_df))
train_size
# Out:
# 633294

# %%
sorted_df = merged_df.sort_values('Date')
train_df, val_df = sorted_df[:train_size], sorted_df[train_size:]

# %%
len(train_df), len(val_df)
# Out:
# (633294, 211098)

# %%
train_df.head()
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1017190   1097          2 2013-01-01   5961       1405     1      0
# 1016179     85          2 2013-01-01   4220        619     1      0
# 1016353    259          2 2013-01-01   6851       1444     1      0
# 1016356    262          2 2013-01-01  17267       2875     1      0
# 1016368    274          2 2013-01-01   3102        729     1      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionDistance  \
# 1017190            a              1         b  ...               720.0
# 1016179            a              1         b  ...              1870.0
# 1016353            a              1         b  ...               210.0
# 1016356            a              1         b  ...              1180.0
# 1016368            a              1         b  ...              3640.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# ...

# %%
val_df.head()
# Out:
#         Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 256637    751          3 2014-12-10   3720        533     1      0
# 256638    752          3 2014-12-10   4258        404     1      0
# 256639    753          3 2014-12-10   7170        654     1      0
# 256640    754          3 2014-12-10   7359        837     1      0
# 256635    748          3 2014-12-10   4579        411     1      0
#
#        StateHoliday  SchoolHoliday StoreType  ... CompetitionDistance  \
# 256637            0              0         a  ...               650.0
# 256638            0              0         a  ...               970.0
# 256639            0              0         d  ...               540.0
# 256640            0              0         c  ...               380.0
# 256635            0              0         d  ...              2380.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 256637                       10.0                    2006.0       0
# ...

# %%
train_df.Date.min(), train_df.Date.max()
# Out:
# (Timestamp('2013-01-01 00:00:00'), Timestamp('2014-12-10 00:00:00'))

# %%
val_df.Date.min(), val_df.Date.max()
# Out:
# (Timestamp('2014-12-10 00:00:00'), Timestamp('2015-07-31 00:00:00'))

# %%
merged_test_df.Date.min(), merged_test_df.Date.max()
# Out:
# (Timestamp('2015-08-01 00:00:00'), Timestamp('2015-09-17 00:00:00'))

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval', 'Day', 'Month', 'Year'],
#       dtype='object')

# %% [markdown]
# # Input and Target columns

# %%
input_cols = ['Store', 'DayOfWeek', 'Promo', 'StateHoliday',
             'StoreType', 'Assortment', 'Day', 'Month', 'Year']

# %%
target_col = 'Sales'

# %% [markdown]
# Lets also separate out numerical and categorical columns.

# %%
merged_df[input_cols].nunique()
# Out:
# Store           1115
# DayOfWeek          7
# Promo              2
# StateHoliday       5
# StoreType          4
# Assortment         3
# Day               31
# Month             12
# Year               3
# dtype: int64

# %%
train_inputs = train_df[input_cols].copy()
train_targets = train_df[target_col].copy()

# %%
val_inputs = val_df[input_cols].copy()
val_targets = val_df[target_col].copy()

# %%
test_inputs=merged_test_df[input_cols].copy()

# %% [markdown]
# Note that some columns can be treated as both numeric and categorical, and its up to you to want to deal with them.

# %%
numeric_cols = ['Store', 'Day', 'Month', 'Year']
categorical_cals = ['DayOfWeek','Promo','StateHoliday','StoreType','Assortment']

# %% [markdown]
# # Imputions, Scaling and Encode
